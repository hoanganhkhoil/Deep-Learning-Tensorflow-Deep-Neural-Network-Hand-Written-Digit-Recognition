# %%
# Author: Khoi Hoang
# Email: hoanganhkhoil@gmail.com
# Python version: 3.6
# Project: Deep Neural Network - Hand written digits recognition

import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import cv2
mnist = input_data.read_data_sets("data", one_hot=True, reshape=True)

# Placeholders
X = tf.placeholder(tf.float32, [None, 784])
Y_ = tf.placeholder(tf.float32, [None, 10])

# Variables
w1 = tf.Variable(tf.truncated_normal([784,200], stddev=0.1))   # layer1_size = 200
b1 = tf.Variable(tf.zeros(200))

w2 = tf.Variable(tf.truncated_normal([200,100], stddev=0.1))   # layer2_size = 100
b2 = tf.Variable(tf.zeros(100))

w3 = tf.Variable(tf.truncated_normal([100,10], stddev=0.1))    # output_size = 10
b3 = tf.Variable(tf.zeros(10))

# Hidden layers
layer1 = tf.nn.relu(tf.matmul(X,w1) + b1)
layer2 = tf.nn.relu(tf.matmul(layer1,w2) + b2)

# Output layer
Y = tf.nn.softmax(tf.matmul(layer2,w3) + b3)

# Cross_entropy
cross_entropy = -tf.reduce_sum(Y_ * tf.log(Y))

# Optimizer
optimizer = tf.train.GradientDescentOptimizer(0.003)
train_step = optimizer.minimize(cross_entropy)

# Accuracy
is_correct = tf.equal(tf.argmax(Y,1), tf.argmax(Y_,1))
Accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

# Tensorflow Initilizer
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# Training
for i in range(10000):
    batch_x, batch_y = mnist.train.next_batch(100)    # batch_size = 100
    train_dict = {X: batch_x, Y_: batch_y}
    sess.run(train_step, feed_dict=train_dict)
    
    # Testing after every 1000 iteration to see the improvement
    if i % 1000 == 0:
        test_dict = {X: mnist.test.images, Y_: mnist.test.labels}
        A,C = sess.run([Accuracy, cross_entropy], feed_dict=test_dict)
        print ("Epoch: %s, Loss: %s, Accuracy: %s" % (i/1000, C, A))

# Testing with actual photos
Y_predict = sess.run(Y, feed_dict={X: mnist.test.images, Y_: mnist.test.labels})
Y_labels = mnist.test.labels

for i in range(10):
    num_1 = np.argmax(Y_predict[i])
    num_2 = np.argmax(Y_labels[i])
    print ("Predicted number: %s" % (num_1))
    print ("Actual number: %s" % (num_2))
    image = (mnist.test.images[i]*255).reshape((28,28))
    cv2.imshow("number", image)
    
    cv2.waitKey(0)        # Press Enter to see next numbers. 

cv2.destroyAllWindows()
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# Epoch: 0.0, Loss: 22538.7, Accuracy: 0.1575
# Epoch: 1.0, Loss: 1073.91, Accuracy: 0.9663
# Epoch: 2.0, Loss: 858.317, Accuracy: 0.9752
# Epoch: 3.0, Loss: 835.471, Accuracy: 0.974
# Epoch: 4.0, Loss: 780.22, Accuracy: 0.9767
# Epoch: 5.0, Loss: 773.939, Accuracy: 0.9792
# Epoch: 6.0, Loss: 817.303, Accuracy: 0.9804
# Epoch: 7.0, Loss: 844.431, Accuracy: 0.9796
# Epoch: 8.0, Loss: 867.672, Accuracy: 0.9797
# Epoch: 9.0, Loss: 857.231, Accuracy: 0.9807
# Predicted number: 7
# Actual number: 7
# Predicted number: 2
# Actual number: 2
# Predicted number: 1
# Actual number: 1
# Predicted number: 0
# Actual number: 0
# Predicted number: 4
# Actual number: 4
# Predicted number: 1
# Actual number: 1
# Predicted number: 4
# Actual number: 4
# Predicted number: 9
# Actual number: 9
# Predicted number: 5
# Actual number: 5
# Predicted number: 9
# Actual number: 9
